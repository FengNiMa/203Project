# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import itertools
from scipy import linalg
import matplotlib as mpl
from sklearn import mixture
import warnings
warnings.filterwarnings("ignore")

# %%
def MoG_generation_2(N=1000):
    # Dataset no.2 
    K = 2
    data_dim = 2
    
    pi = np.ones(K) / K
    mu = np.array([(3.0, 3.0), (3.0, 3.0)])
    cov = np.array([[[2.8, -2.8], [0.07, 0.07]],
                   [[2.8, 2.8], [-0.07, 0.07]]])
    adv_l = [(1.0, 3.0), (5.0, 3.0)]
    adv_sample = np.array(adv_l)
    
    samples = np.array([])
    while len(samples) < N:
        cls = np.random.randint(K)
        if not len(samples):
            samples = np.random.multivariate_normal(mu[cls], cov[cls], 10)
        samples = np.vstack([samples, np.random.multivariate_normal(mu[cls], cov[cls], 10)])
        
    samples = list(samples)
    i = 0
    while i < len(samples):
        if 2 <= samples[i][0] <= 4:
            del samples[i]
        else:
            i += 1
    
    return pi, mu, cov, np.array(samples), adv_sample

def MoG_generation_3(N=1000):
    # Dataset no.3
    K = 2
    data_dim = 2
    
    pi = np.ones(K) / K
    mu = np.array([(1.0, 3.0), (4.0, 3.0)])
    cov = np.array([[[0.8, 0], [0, 0.1]],
                   [[0.1, 0], [0, 0.1]]])
    adv_l = [(3.0, 3.0)]
    adv_sample = np.array(adv_l)
    
    samples = np.array([])
    while len(samples) < N:
        cls = np.random.randint(K)
        if not len(samples):
            samples = np.random.multivariate_normal(mu[cls], cov[cls], 10)
        samples = np.vstack([samples, np.random.multivariate_normal(mu[cls], cov[cls], 10)])
        
    samples = list(samples)
    i = 0
    while i < len(samples):
        if 0.0 <= samples[i][0] <= 1.2:
            del samples[i]
        else:
            i += 1
    
    return pi, mu, cov, np.array(samples), adv_sample

def MoG_prob(x, pi, mu, cov=None):
    K, dim = mu.shape
    if cov is None:
        cov = np.tile(np.eye(dim), (K, 1, 1))
    assert x.shape == (dim,)
    assert pi.shape == (K,)
    assert cov.shape == (K, dim, dim)
    prob = 0.0
    for k in range(K):
        s, logdet = np.linalg.slogdet(cov[k] + np.eye(dim) * 1e-6)
        # print(s, np.exp(logdet))
        assert s > 0
        log_prob_k = -dim * 0.5 * math.log(2 * math.pi) - 0.5 * logdet - 0.5 * (x - mu[k]).dot(x - mu[k])
        prob += np.exp(log_prob_k) * pi[k]
    return prob

def MoG_plot(pi, mu, cov=None):
    plt.figure(figsize=(5, 5))
    
    x1 = np.linspace(-2.0, 8.0, 101)
    x2 = np.linspace(-2.0, 8.0, 101)
    p_lists = []
    for _x2 in x2:
        p = []
        for _x1 in x1:
            p.append(MoG_prob(np.array((_x1, _x2)), pi, mu, cov) )
        p_lists.append(p)
    P = np.array(p_lists)
    
    plt.imshow(P, origin='lower', interpolation='bilinear')
    plt.xticks(np.linspace(0, 100, 6), np.linspace(-2, 8, 6))
    plt.yticks(np.linspace(0, 100, 6), np.linspace(-2, 8, 6))

def Data_plot(samples, adv_sample):
    plt.figure(figsize=(5, 5))

    x1 = [x[0] for x in samples]
    x2 = [x[1] for x in samples]
    plt.scatter(x1, x2, s=5, marker='o')
    
    x1 = [x[0] for x in adv_sample]
    x2 = [x[1] for x in adv_sample]
    plt.scatter(x1, x2, s=30, marker='X')
    
    plt.xlim(-2, 8)
    plt.ylim(-2, 8)

def plot_gmm_results(X, Y, means, covariances, index, title):
    color_iter = itertools.cycle(['navy', 'c', 'darkorange'])
    plt.figure(figsize=(10, 10))
    splot = plt.subplot(1, 1, 1 + index)
    for i, (mean, covar, color) in enumerate(zip(
            means, covariances, color_iter)):
        v, w = linalg.eigh(covar)
        v = 2. * np.sqrt(2.) * np.sqrt(v)
        u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        if not np.any(Y == i):
            continue
        plt.scatter(X[Y == i, 0], X[Y == i, 1], .8, color=color)

        # Plot an ellipse to show the Gaussian component
        angle = np.arctan(u[1] / u[0])
        angle = 180. * angle / np.pi  # convert to degrees
        ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
        ell.set_clip_box(splot.bbox)
        ell.set_alpha(0.5)
        splot.add_artist(ell)

    plt.xlim(-2, 8)
    plt.ylim(-2, 8)
    plt.title(title)
    plt.xticks(())
    plt.yticks(())

# %%
pi, mu, cov, samples, adv_sample = MoG_generation_2()
MoG_plot(pi, mu, cov)
#plt.savefig('figures/multi-adv-2/True.png')
plt.show()

# %%
pi, mu, cov, samples, adv_sample = MoG_generation_2()
Data_plot(samples, adv_sample)
#plt.savefig('figures/multi-adv-2/Dataset.png')
plt.show()
gmm = mixture.GaussianMixture(n_components=2, covariance_type='full',
                              max_iter=100).fit(samples)
plot_gmm_results(samples, gmm.predict(samples), gmm.means_, gmm.covariances_, 0,
                 'Expectation-maximization')

# %%
pi, mu, cov, samples, adv_sample = MoG_generation_3()
Data_plot(samples, adv_sample)
#plt.savefig('figures/multi-adv-2/Dataset.png')
plt.show()
gmm = mixture.GaussianMixture(n_components=2, covariance_type='full',
                              max_iter=100).fit(samples)
plot_gmm_results(samples, gmm.predict(samples), gmm.means_, gmm.covariances_, 0,
                 'Expectation-maximization')

# %% [markdown]
# ## ------

# %%
data_fname = 'data_multi_adv.npz'
load_data = np.load(data_fname)
true_pi = load_data['pi']
true_mu = load_data['mu']
samples_100 = load_data['samples']
adv_sample = load_data['adv_sample']

# %%
MoG_plot(true_pi,true_mu)

# %%
len(samples)

# %%
K=5
data_dim=2
data_range=6.0
data_n=100
samples_list = []

while len(samples_list) < 1000:
    normal_sample = np.random.randn(data_dim)
    cls = np.random.randint(K)
    sample = normal_sample + true_mu[cls]
    if -.5 < sample[0] < 6.5 and -.5 < sample[1] < 6.5:
        samples_list.append(sample)
samples = np.array(samples_list)

# %%
Data_plot(samples_100, adv_sample)
plt.savefig('figures/Dataset-100.png')
plt.show()

# %%
adv_sample= [(0, 3), (3, 0), (3, 6), (6, 3)]

# %%
Data_plot(samples, adv_sample)
plt.savefig('figures/Dataset-1000.png')
plt.show()

# %%
from sklearn.mixture import GaussianMixture

gmm = GaussianMixture(n_components=2) 

gmm.weights_ = pi
gmm.means_ = mu
gmm.covariances_ = np.array([np.eye(2)] * 5)
